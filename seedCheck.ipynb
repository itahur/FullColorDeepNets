# %%
import numpy as np
import seaborn as sns
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
from tqdm import tqdm
from small2DNet import small2DNet
from util import add_color, colorize, colorize_gaussian, calculate_correct_loss
from colorMNist import colorMNist
import random
import colorsys
import pickle
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

# %%
model_layers = [8, 8, "M", 16,"M"]
torch.manual_seed(12)
model = small2DNet(model_layers, 16)
model.cuda()
# torch.manual_seed(12)
model2 = small2DNet(model_layers, 16)
model2.cuda()
hi = 5

# %%
children = [x for x in model.children()]
children2 = [x for x in model2.children()]
weight = []
weight2 = []
# children2[0][0].weight = children[0][0].weight
for i in range(len(children[0])):
    if hasattr(children[0][i], "weight"):
        weight.append(children[0][i].weight)
    if hasattr(children2[0][i], "weight"):
        weight2.append(children2[0][i].weight)

print(weight[0] == weight2[0])
# Out:
# tensor([[[[False, False, False],
#           [False, False, False],
#           [False, False, False]],
#
#          [[False, False, False],
#           [False, False, False],
#           [False, False, False]],
#
#          [[False, False, False],
#           [False, False, False],
#           [False, False, False]]],
#
#
#         [[[False, False, False],
#           [False, False, False],
#           [False, False, False]],
#
#          [[False, False, False],
#           [False, False, False],
#           [False, False, False]],
#
#          [[False, False, False],
#           [False, False, False],
#           [False, False, False]]],
#
#
#         [[[False, False, False],
#           [False, False, False],
#           [False, False, False]],
#
#          [[False, False, False],
#           [False, False, False],
#           [False, False, False]],
#
#          [[False, False, False],
#           [False, False, False],
#           [False, False, False]]],
#
#
# ...
